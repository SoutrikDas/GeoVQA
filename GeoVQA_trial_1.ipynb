# %%
# !pip install huggingface
# Out:
# Requirement already satisfied: huggingface in /usr/local/lib/python3.12/dist-packages (0.0.1)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="auto",
    trust_remote_code=True,
)
# Disable caching in the model's configuration
model.config.use_cache = False

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

# %%
prompt = "Write an email aplogising to Sarah for the tragic gardening mishap. Explain how it happened <|assistant|>"

# %%
# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors = "pt").input_ids.to("cuda")

# %%
# Genrate the text
generation_output = model.generate(
    input_ids = input_ids,
    max_new_tokens = 40,
    use_cache=False
)

# %%
# Print the output
print(tokenizer.decode(generation_output[0]))
